# %% [markdown]
# ### 勾配爆発への対策

# %%
import numpy as np
dW1 = np.random.randn(3, 3) * 10
dW2 = np.random.randn(3, 3) * 10
grads = [dW1, dW2]
max_norm = 5.0

def clip_grads(grads, max_norm):
    total_norm = 0
    for grad in grads:
        total_norm += np.sum(grad ** 2)
    total_norm = np.sqrt(total_norm)

    rate = max_norm / (total_norm + 1e-6)
    if rate < 1:
        for grad in grads:
            grad *= rate

clip_grads(grads, max_norm)

# %% [markdown]
# ### LSTMの実装

# %%
import functions

# %%
class LSTM:
    def __init__(self, Wx, Wh, b):
        self.params = [Wx, Wh, b]
        self.grads = [np.zeros_like(Wx), np.zeros_like(Wh), np.zeros_like(b)]
        self.cache = None
    
    def forward(self, x, h_prev, c_prev):
        Wx, Wh, b = self.params
        N, H = h_prev.shape

        A = np.dot(x, Wx) + np.dot(h_prev, Wh) + b

        # slice
        f = A[:, :H]
        g = A[:, H:2*H]
        i = A[:, 2*H:3*H]
        o = A[:, 3*H:]

        f = functions.sigmoid(f)
        g = np.tanh(g)
        i = functions.sigmoid(i)
        o = functions.sigmoid(o)

        c_next = f * c_prev + g * i
        h_next = o * np.tanh(c_next)

        self.cache = (x, h_prev, c_prev, i, f, g, o, c_next)
        return h_next, c_next

# %% [markdown]
# ### TimeLSTMの実装

# %%
class TimeLSTM:
    def __init__(self, Wx, Wh, b, stateful=False):
        self.params = [Wx, Wh, b]
        self.grads = [np.zeros_like(Wx), np.zeros_like(Wh), np.zeros_like(b)]
        self.layers = None
    
    def forward(self, xs):
        Wx, Wh, b = self.params
        N, T, D = xs.shape
        H = Wh.shape[0]

        self.layers = []
        hs = np.empyu((N, T, H), dtype='f')

        if not self.stateful or self.h is None:
            self.h = np.zeros((N, H), dtype='f')
        if not self.stateful or self.c is None:
            self.c = np.zeros((N, H), dtype='f')
        
        for t in range(T):
            layer = LSTM(*self.params)
            self.h, self.c = layer.forward(xs[:, t, :], self.h, self.c)
            hs[:, t, :] = self.h

            self.layers.append(layer)
        return hs
    
    def backward(self, dhs):
        Wx, Wh, b = self.params
        N, T, H = dhs.shape
        D = Wx.shape[0]

        dxs = np.empty((N, T, D), dtype='f')
        dh, dc = 0, 0

        grads = [0, 0, 0]
        for t in reversed(range(T)):
            layer = self.layers[t]
            dx, dh, dc = layer.backward(dhs[:, t, :] + dh, dc)
            dxs[:, t, :] = dx
            for i, grad in enumerate(layer.grads):
                grads[i] += grad
        
        for i, grad in enumerate(grads):
            self.grads[i][...] = grad
        
        self.dh = dh
        return dxs
    
    def set_state(self, h, c=None):
        self.h, self.c = h, c
    
    def reset_state(self):
        self.h, self.c = None, None

# %% [markdown]
# ### LSTMを使った言語モデル

# %%
import pickle
import time_layers

# %%
class Rnnlm:
    def __init__(self, vocab_size=10000, wordvec_size=100, hidden_size=100):
        V, D, H = vocab_size , wordvec_size, hidden_size
        rn = np.random.randn

        # 重みの初期化
        embed_W = (rn(V, D) / 100).astype('f')
        lstm_Wx = (rn(D, 4 * H) / np.sqrt(D)).astype('f')
        lstm_Wh = (rn(H, 4 * H) / np.sqrt(H)).astype('f')
        lstm_b = np.zeros(4 * H).astype('f')
        affine_W = (rn(H, V) / np.sqrt(H)).astype('f')
        affine_b = np.zeros(V).astype('f')

        # レイヤの生成
        self.layers = [
            time_layers.TimeEmbedding(embed_W),
            time_layers.TimeLSTM(lstm_Wx, lstm_Wh, lstm_b, stateful=True),
            time_layers.TimeAffine(affine_W, affine_b)
        ]
        self.loss_layer = time_layers.TimeSoftmaxWithLoss()
        self.lstm_layer = self.layers[1]

        # 全ての重みと勾配をリストにまとめる
        self.params, self.grads = [], []
        for layer in self.layers:
            self.params += layer.params
            self.grads += layer.grads
    
    def predict(self, xs):
        for layer in self.layers:
            xs = layer.forward(xs)
        return xs
    
    def forward(self, xs, ts):
        score = self.predict(xs)
        loss = self.loss_layer.forward(score, ts)
        return loss
    
    def backward(self, dout=1):
        dout = self.loss_layer.backward(dout)
        for layer in reversed(self.layers):
            dout = layer.backward(dout)
        return dout
    
    def reset_state(self):
        self.lstm_layer.reset_state()
    
    def save_params(self, file_name='Rnnlm.pkl'):
        with open(file_name, 'wb') as f:
            pickle.dump(self.params, f)
    
    def load_params(self, file_name='Rnnlm.pkl'):
        with open(file_name, 'rb') as f:
            self.params = pickle.load(f)

# %% [markdown]
# ### 学習

# %%
import optimizer
import trainer
import util
import ptb

# %%
# ハイパーパラメータの設定
batch_size = 20
wordvec_size = 100
hidden_size = 100 # RNNの隠れ状態ベクトルの要素数
time_size = 35 # RNNを展開するサイズ
lr = 20.0
max_epoch = 4
max_grad = 0.25

# 学習データの読み込み
corpus, word_to_id, id_to_word = ptb.load_data('train')
corpus_test, _, _ = ptb.load_data('test')
vocab_size = len(word_to_id)
xs = corpus[:-1]
ts = corpus[1:]

# モデルの生成
model = Rnnlm(vocab_size, wordvec_size, hidden_size)
optimizer = optimizer.SGD(lr)
trainer = trainer.RnnlmTrainer(model, optimizer)

# ①勾配クリップングを適用して学習
trainer.fit(xs, ts, max_epoch, batch_size, time_size, max_grad, eval_interval=20)
trainer.plot(ylim=(0, 500))

# ②テストデータで評価
model.reset_state()
ppl_test = util.eval_perplexity(model, corpus_test)
print('test perplexity:', ppl_test)

# ③パラメータの保存
model.save_params()
# Out:
# | epoch 1 |  iter 1 / 1327 | time 0[s] | perplexity 9999.78
# | epoch 1 |  iter 21 / 1327 | time 7[s] | perplexity 3049.02
# | epoch 1 |  iter 41 / 1327 | time 14[s] | perplexity 1207.01
# | epoch 1 |  iter 61 / 1327 | time 20[s] | perplexity 985.55
# | epoch 1 |  iter 81 / 1327 | time 27[s] | perplexity 803.29
# | epoch 1 |  iter 101 / 1327 | time 33[s] | perplexity 649.42
# | epoch 1 |  iter 121 / 1327 | time 40[s] | perplexity 656.30
# | epoch 1 |  iter 141 / 1327 | time 46[s] | perplexity 597.16
# | epoch 1 |  iter 161 / 1327 | time 53[s] | perplexity 582.15
# | epoch 1 |  iter 181 / 1327 | time 60[s] | perplexity 576.57
# | epoch 1 |  iter 201 / 1327 | time 66[s] | perplexity 494.03
# | epoch 1 |  iter 221 / 1327 | time 73[s] | perplexity 499.45
# | epoch 1 |  iter 241 / 1327 | time 79[s] | perplexity 450.35
# | epoch 1 |  iter 261 / 1327 | time 86[s] | perplexity 445.00
# | epoch 1 |  iter 281 / 1327 | time 92[s] | perplexity 449.63
# | epoch 1 |  iter 301 / 1327 | time 99[s] | perplexity 400.35
# | epoch 1 |  iter 321 / 1327 | time 105[s] | perplexity 346.25
# | epoch 1 |  iter 341 / 1327 | time 112[s] | perplexity 401.39
# | epoch 1 |  iter 361 / 1327 | time 118[s] | perplexity 407.78
# | epoch 1 |  iter 381 / 1327 | time 125[s] | perplexity 334.16
# | epoch 1 |  iter 401 / 1327 | time 132[s] | perplexity 352.90
# | epoch 1 |  iter 421 / 1327 | time 138[s] | perplexity 342.23
# | epoch 1 |  iter 441 / 1327 | time 145[s] | perplexity 326.75
# | epoch 1 |  iter 461 / 1327 | time 151[s] | perplexity 325.70
# | epoch 1 |  iter 481 / 1327 | time 158[s] | perplexity 305.91
# | epoch 1 |  iter 501 / 1327 | time 164[s] | perplexity 310.93
# | epoch 1 |  iter 521 / 1327 | time 171[s] | perplexity 305.19
# | epoch 1 |  iter 541 / 1327 | time 177[s] | perplexity 316.09
# | epoch 1 |  iter 561 / 1327 | time 184[s] | perplexity 284.16
# | epoch 1 |  iter 581 / 1327 | time 190[s] | perplexity 253.70
# | epoch 1 |  iter 601 / 1327 | time 197[s] | perplexity 338.73
# | epoch 1 |  iter 621 / 1327 | time 203[s] | perplexity 308.12
# | epoch 1 |  iter 641 / 1327 | time 210[s] | perplexity 283.34
# | epoch 1 |  iter 661 / 1327 | time 216[s] | perplexity 269.60
# | epoch 1 |  iter 681 / 1327 | time 223[s] | perplexity 231.51
# | epoch 1 |  iter 701 / 1327 | time 229[s] | perplexity 250.09
# | epoch 1 |  iter 721 / 1327 | time 236[s] | perplexity 258.91
# | epoch 1 |  iter 741 / 1327 | time 243[s] | perplexity 220.37
# | epoch 1 |  iter 761 / 1327 | time 249[s] | perplexity 232.56
# | epoch 1 |  iter 781 / 1327 | time 256[s] | perplexity 219.77
# | epoch 1 |  iter 801 / 1327 | time 262[s] | perplexity 240.25
# | epoch 1 |  iter 821 / 1327 | time 269[s] | perplexity 225.45
# | epoch 1 |  iter 841 / 1327 | time 275[s] | perplexity 229.63
# | epoch 1 |  iter 861 / 1327 | time 282[s] | perplexity 221.54
# | epoch 1 |  iter 881 / 1327 | time 288[s] | perplexity 205.64
# | epoch 1 |  iter 901 / 1327 | time 295[s] | perplexity 254.57
# | epoch 1 |  iter 921 / 1327 | time 301[s] | perplexity 228.66
# | epoch 1 |  iter 941 / 1327 | time 308[s] | perplexity 230.53
# | epoch 1 |  iter 961 / 1327 | time 314[s] | perplexity 243.61
# | epoch 1 |  iter 981 / 1327 | time 321[s] | perplexity 229.23
# | epoch 1 |  iter 1001 / 1327 | time 327[s] | perplexity 192.46
# | epoch 1 |  iter 1021 / 1327 | time 334[s] | perplexity 226.32
# | epoch 1 |  iter 1041 / 1327 | time 340[s] | perplexity 206.00
# | epoch 1 |  iter 1061 / 1327 | time 347[s] | perplexity 199.66
# | epoch 1 |  iter 1081 / 1327 | time 353[s] | perplexity 170.29
# | epoch 1 |  iter 1101 / 1327 | time 360[s] | perplexity 193.38
# | epoch 1 |  iter 1121 / 1327 | time 366[s] | perplexity 228.12
# | epoch 1 |  iter 1141 / 1327 | time 373[s] | perplexity 207.31
# | epoch 1 |  iter 1161 / 1327 | time 379[s] | perplexity 197.54
# | epoch 1 |  iter 1181 / 1327 | time 386[s] | perplexity 192.05
# | epoch 1 |  iter 1201 / 1327 | time 392[s] | perplexity 164.10
# | epoch 1 |  iter 1221 / 1327 | time 399[s] | perplexity 160.49
# | epoch 1 |  iter 1241 / 1327 | time 405[s] | perplexity 188.91
# | epoch 1 |  iter 1261 / 1327 | time 412[s] | perplexity 171.58
# | epoch 1 |  iter 1281 / 1327 | time 418[s] | perplexity 177.81
# | epoch 1 |  iter 1301 / 1327 | time 425[s] | perplexity 222.76
# | epoch 1 |  iter 1321 / 1327 | time 431[s] | perplexity 210.39
# | epoch 2 |  iter 1 / 1327 | time 433[s] | perplexity 225.48
# | epoch 2 |  iter 21 / 1327 | time 440[s] | perplexity 206.67
# | epoch 2 |  iter 41 / 1327 | time 446[s] | perplexity 188.78
# | epoch 2 |  iter 61 / 1327 | time 453[s] | perplexity 175.63
# | epoch 2 |  iter 81 / 1327 | time 461[s] | perplexity 158.80
# | epoch 2 |  iter 101 / 1327 | time 467[s] | perplexity 152.93
# | epoch 2 |  iter 121 / 1327 | time 474[s] | perplexity 159.87
# | epoch 2 |  iter 141 / 1327 | time 480[s] | perplexity 178.49
# | epoch 2 |  iter 161 / 1327 | time 487[s] | perplexity 192.39
# | epoch 2 |  iter 181 / 1327 | time 493[s] | perplexity 200.84
# | epoch 2 |  iter 201 / 1327 | time 500[s] | perplexity 186.07
# | epoch 2 |  iter 221 / 1327 | time 506[s] | perplexity 184.37
# | epoch 2 |  iter 241 / 1327 | time 513[s] | perplexity 177.34
# | epoch 2 |  iter 261 / 1327 | time 519[s] | perplexity 186.53
# | epoch 2 |  iter 281 / 1327 | time 526[s] | perplexity 187.82
# | epoch 2 |  iter 301 / 1327 | time 532[s] | perplexity 167.48
# | epoch 2 |  iter 321 / 1327 | time 539[s] | perplexity 138.80
# | epoch 2 |  iter 341 / 1327 | time 545[s] | perplexity 171.18
# | epoch 2 |  iter 361 / 1327 | time 552[s] | perplexity 198.52
# | epoch 2 |  iter 381 / 1327 | time 558[s] | perplexity 154.71
# | epoch 2 |  iter 401 / 1327 | time 564[s] | perplexity 170.34
# | epoch 2 |  iter 421 / 1327 | time 571[s] | perplexity 156.45
# | epoch 2 |  iter 441 / 1327 | time 577[s] | perplexity 163.22
# | epoch 2 |  iter 461 / 1327 | time 584[s] | perplexity 158.20
# | epoch 2 |  iter 481 / 1327 | time 590[s] | perplexity 157.81
# | epoch 2 |  iter 501 / 1327 | time 597[s] | perplexity 171.47
# | epoch 2 |  iter 521 / 1327 | time 603[s] | perplexity 174.71
# | epoch 2 |  iter 541 / 1327 | time 610[s] | perplexity 176.11
# | epoch 2 |  iter 561 / 1327 | time 616[s] | perplexity 156.00
# | epoch 2 |  iter 581 / 1327 | time 622[s] | perplexity 140.06
# | epoch 2 |  iter 601 / 1327 | time 629[s] | perplexity 190.83
# | epoch 2 |  iter 621 / 1327 | time 635[s] | perplexity 183.59
# | epoch 2 |  iter 641 / 1327 | time 642[s] | perplexity 165.54
# | epoch 2 |  iter 661 / 1327 | time 648[s] | perplexity 154.75
# | epoch 2 |  iter 681 / 1327 | time 655[s] | perplexity 131.53
# | epoch 2 |  iter 701 / 1327 | time 661[s] | perplexity 152.85
# | epoch 2 |  iter 721 / 1327 | time 668[s] | perplexity 161.40
# | epoch 2 |  iter 741 / 1327 | time 674[s] | perplexity 135.08
# | epoch 2 |  iter 761 / 1327 | time 680[s] | perplexity 133.27
# | epoch 2 |  iter 781 / 1327 | time 687[s] | perplexity 136.51
# | epoch 2 |  iter 801 / 1327 | time 693[s] | perplexity 148.86
# | epoch 2 |  iter 821 / 1327 | time 700[s] | perplexity 145.36
# | epoch 2 |  iter 841 / 1327 | time 706[s] | perplexity 145.52
# | epoch 2 |  iter 861 / 1327 | time 713[s] | perplexity 147.79
# | epoch 2 |  iter 881 / 1327 | time 719[s] | perplexity 131.57
# | epoch 2 |  iter 901 / 1327 | time 725[s] | perplexity 167.22
# | epoch 2 |  iter 921 / 1327 | time 732[s] | perplexity 147.32
# | epoch 2 |  iter 941 / 1327 | time 738[s] | perplexity 153.96
# | epoch 2 |  iter 961 / 1327 | time 745[s] | perplexity 164.93
# | epoch 2 |  iter 981 / 1327 | time 751[s] | perplexity 155.22
# | epoch 2 |  iter 1001 / 1327 | time 757[s] | perplexity 132.58
# | epoch 2 |  iter 1021 / 1327 | time 764[s] | perplexity 156.33
# | epoch 2 |  iter 1041 / 1327 | time 770[s] | perplexity 144.58
# | epoch 2 |  iter 1061 / 1327 | time 776[s] | perplexity 129.13
# | epoch 2 |  iter 1081 / 1327 | time 783[s] | perplexity 112.58
# | epoch 2 |  iter 1101 / 1327 | time 789[s] | perplexity 122.53
# | epoch 2 |  iter 1121 / 1327 | time 795[s] | perplexity 155.42
# | epoch 2 |  iter 1141 / 1327 | time 802[s] | perplexity 143.15
# | epoch 2 |  iter 1161 / 1327 | time 808[s] | perplexity 134.49
# | epoch 2 |  iter 1181 / 1327 | time 814[s] | perplexity 136.62
# | epoch 2 |  iter 1201 / 1327 | time 821[s] | perplexity 114.22
# | epoch 2 |  iter 1221 / 1327 | time 827[s] | perplexity 110.98
# | epoch 2 |  iter 1241 / 1327 | time 833[s] | perplexity 131.47
# | epoch 2 |  iter 1261 / 1327 | time 840[s] | perplexity 124.79
# | epoch 2 |  iter 1281 / 1327 | time 846[s] | perplexity 122.58
# | epoch 2 |  iter 1301 / 1327 | time 852[s] | perplexity 158.54
# | epoch 2 |  iter 1321 / 1327 | time 859[s] | perplexity 154.35
# | epoch 3 |  iter 1 / 1327 | time 861[s] | perplexity 163.10
# | epoch 3 |  iter 21 / 1327 | time 867[s] | perplexity 145.14
# | epoch 3 |  iter 41 / 1327 | time 874[s] | perplexity 135.41
# | epoch 3 |  iter 61 / 1327 | time 880[s] | perplexity 128.30
# | epoch 3 |  iter 81 / 1327 | time 886[s] | perplexity 119.41
# | epoch 3 |  iter 101 / 1327 | time 893[s] | perplexity 106.62
# | epoch 3 |  iter 121 / 1327 | time 899[s] | perplexity 118.32
# | epoch 3 |  iter 141 / 1327 | time 905[s] | perplexity 126.99
# | epoch 3 |  iter 161 / 1327 | time 912[s] | perplexity 143.78
# | epoch 3 |  iter 181 / 1327 | time 918[s] | perplexity 152.49
# | epoch 3 |  iter 201 / 1327 | time 924[s] | perplexity 140.72
# | epoch 3 |  iter 221 / 1327 | time 931[s] | perplexity 143.13
# | epoch 3 |  iter 241 / 1327 | time 937[s] | perplexity 136.24
# | epoch 3 |  iter 261 / 1327 | time 943[s] | perplexity 142.00
# | epoch 3 |  iter 281 / 1327 | time 950[s] | perplexity 143.80
# | epoch 3 |  iter 301 / 1327 | time 956[s] | perplexity 124.80
# | epoch 3 |  iter 321 / 1327 | time 962[s] | perplexity 103.56
# | epoch 3 |  iter 341 / 1327 | time 969[s] | perplexity 127.84
# | epoch 3 |  iter 361 / 1327 | time 975[s] | perplexity 154.66
# | epoch 3 |  iter 381 / 1327 | time 982[s] | perplexity 118.11
# | epoch 3 |  iter 401 / 1327 | time 988[s] | perplexity 133.40
# | epoch 3 |  iter 421 / 1327 | time 994[s] | perplexity 115.47
# | epoch 3 |  iter 441 / 1327 | time 1001[s] | perplexity 125.16
# | epoch 3 |  iter 461 / 1327 | time 1007[s] | perplexity 119.83
# | epoch 3 |  iter 481 / 1327 | time 1013[s] | perplexity 121.27
# | epoch 3 |  iter 501 / 1327 | time 1020[s] | perplexity 130.30
# | epoch 3 |  iter 521 / 1327 | time 1026[s] | perplexity 138.68
# | epoch 3 |  iter 541 / 1327 | time 1032[s] | perplexity 139.81
# | epoch 3 |  iter 561 / 1327 | time 1039[s] | perplexity 119.77
# | epoch 3 |  iter 581 / 1327 | time 1045[s] | perplexity 107.20
# | epoch 3 |  iter 601 / 1327 | time 1051[s] | perplexity 152.12
# | epoch 3 |  iter 621 / 1327 | time 1058[s] | perplexity 146.13
# | epoch 3 |  iter 641 / 1327 | time 1064[s] | perplexity 131.83
# | epoch 3 |  iter 661 / 1327 | time 1070[s] | perplexity 121.48
# | epoch 3 |  iter 681 / 1327 | time 1077[s] | perplexity 101.35
# | epoch 3 |  iter 701 / 1327 | time 1083[s] | perplexity 121.31
# | epoch 3 |  iter 721 / 1327 | time 1089[s] | perplexity 128.58
# | epoch 3 |  iter 741 / 1327 | time 1096[s] | perplexity 109.82
# | epoch 3 |  iter 761 / 1327 | time 1102[s] | perplexity 104.56
# | epoch 3 |  iter 781 / 1327 | time 1108[s] | perplexity 105.66
# | epoch 3 |  iter 801 / 1327 | time 1115[s] | perplexity 117.11
# | epoch 3 |  iter 821 / 1327 | time 1121[s] | perplexity 118.04
# | epoch 3 |  iter 841 / 1327 | time 1127[s] | perplexity 115.58
# | epoch 3 |  iter 861 / 1327 | time 1134[s] | perplexity 123.02
# | epoch 3 |  iter 881 / 1327 | time 1140[s] | perplexity 107.93
# | epoch 3 |  iter 901 / 1327 | time 1146[s] | perplexity 133.40
# | epoch 3 |  iter 921 / 1327 | time 1153[s] | perplexity 120.72
# | epoch 3 |  iter 941 / 1327 | time 1159[s] | perplexity 127.30
# | epoch 3 |  iter 961 / 1327 | time 1165[s] | perplexity 133.05
# | epoch 3 |  iter 981 / 1327 | time 1172[s] | perplexity 125.24
# | epoch 3 |  iter 1001 / 1327 | time 1178[s] | perplexity 111.05
# | epoch 3 |  iter 1021 / 1327 | time 1184[s] | perplexity 128.42
# | epoch 3 |  iter 1041 / 1327 | time 1191[s] | perplexity 121.21
# | epoch 3 |  iter 1061 / 1327 | time 1197[s] | perplexity 103.93
# | epoch 3 |  iter 1081 / 1327 | time 1203[s] | perplexity 90.18
# | epoch 3 |  iter 1101 / 1327 | time 1210[s] | perplexity 96.21
# | epoch 3 |  iter 1121 / 1327 | time 1216[s] | perplexity 123.61
# | epoch 3 |  iter 1141 / 1327 | time 1222[s] | perplexity 116.29
# | epoch 3 |  iter 1161 / 1327 | time 1229[s] | perplexity 107.31
# | epoch 3 |  iter 1181 / 1327 | time 1235[s] | perplexity 112.47
# | epoch 3 |  iter 1201 / 1327 | time 1241[s] | perplexity 95.53
# | epoch 3 |  iter 1221 / 1327 | time 1248[s] | perplexity 90.06
# | epoch 3 |  iter 1241 / 1327 | time 1254[s] | perplexity 106.39
# | epoch 3 |  iter 1261 / 1327 | time 1260[s] | perplexity 106.36
# | epoch 3 |  iter 1281 / 1327 | time 1267[s] | perplexity 100.75
# | epoch 3 |  iter 1301 / 1327 | time 1273[s] | perplexity 130.40
# | epoch 3 |  iter 1321 / 1327 | time 1279[s] | perplexity 128.56
# | epoch 4 |  iter 1 / 1327 | time 1281[s] | perplexity 136.27
# | epoch 4 |  iter 21 / 1327 | time 1288[s] | perplexity 124.07
# | epoch 4 |  iter 41 / 1327 | time 1294[s] | perplexity 108.09
# | epoch 4 |  iter 61 / 1327 | time 1301[s] | perplexity 108.11
# | epoch 4 |  iter 81 / 1327 | time 1307[s] | perplexity 97.13
# | epoch 4 |  iter 101 / 1327 | time 1313[s] | perplexity 88.04
# | epoch 4 |  iter 121 / 1327 | time 1320[s] | perplexity 97.51
# | epoch 4 |  iter 141 / 1327 | time 1326[s] | perplexity 104.52
# | epoch 4 |  iter 161 / 1327 | time 1332[s] | perplexity 118.91
# | epoch 4 |  iter 181 / 1327 | time 1338[s] | perplexity 130.64
# | epoch 4 |  iter 201 / 1327 | time 1345[s] | perplexity 120.27
# | epoch 4 |  iter 221 / 1327 | time 1351[s] | perplexity 123.56
# | epoch 4 |  iter 241 / 1327 | time 1357[s] | perplexity 114.79
# | epoch 4 |  iter 261 / 1327 | time 1364[s] | perplexity 116.80
# | epoch 4 |  iter 281 / 1327 | time 1370[s] | perplexity 122.99
# | epoch 4 |  iter 301 / 1327 | time 1376[s] | perplexity 105.52
# | epoch 4 |  iter 321 / 1327 | time 1383[s] | perplexity 86.49
# | epoch 4 |  iter 341 / 1327 | time 1389[s] | perplexity 101.90
# | epoch 4 |  iter 361 / 1327 | time 1397[s] | perplexity 130.32
# | epoch 4 |  iter 381 / 1327 | time 1404[s] | perplexity 99.75
# | epoch 4 |  iter 401 / 1327 | time 1411[s] | perplexity 112.68
# | epoch 4 |  iter 421 / 1327 | time 1417[s] | perplexity 95.78
# | epoch 4 |  iter 441 / 1327 | time 1423[s] | perplexity 104.75
# | epoch 4 |  iter 461 / 1327 | time 1429[s] | perplexity 101.38
# | epoch 4 |  iter 481 / 1327 | time 1436[s] | perplexity 104.99
# | epoch 4 |  iter 501 / 1327 | time 1442[s] | perplexity 109.21
# | epoch 4 |  iter 521 / 1327 | time 1449[s] | perplexity 119.03
# | epoch 4 |  iter 541 / 1327 | time 1455[s] | perplexity 114.87
# | epoch 4 |  iter 561 / 1327 | time 1461[s] | perplexity 104.08
# | epoch 4 |  iter 581 / 1327 | time 1468[s] | perplexity 90.56
# | epoch 4 |  iter 601 / 1327 | time 1474[s] | perplexity 129.43
# | epoch 4 |  iter 621 / 1327 | time 1480[s] | perplexity 124.52
# | epoch 4 |  iter 641 / 1327 | time 1487[s] | perplexity 112.08
# | epoch 4 |  iter 661 / 1327 | time 1493[s] | perplexity 103.69
# | epoch 4 |  iter 681 / 1327 | time 1500[s] | perplexity 85.93
# | epoch 4 |  iter 701 / 1327 | time 1506[s] | perplexity 103.93
# | epoch 4 |  iter 721 / 1327 | time 1512[s] | perplexity 108.66
# | epoch 4 |  iter 741 / 1327 | time 1519[s] | perplexity 97.33
# | epoch 4 |  iter 761 / 1327 | time 1525[s] | perplexity 89.62
# | epoch 4 |  iter 781 / 1327 | time 1531[s] | perplexity 87.90
# | epoch 4 |  iter 801 / 1327 | time 1538[s] | perplexity 99.82
# | epoch 4 |  iter 821 / 1327 | time 1544[s] | perplexity 103.35
# | epoch 4 |  iter 841 / 1327 | time 1550[s] | perplexity 99.28
# | epoch 4 |  iter 861 / 1327 | time 1557[s] | perplexity 106.14
# | epoch 4 |  iter 881 / 1327 | time 1563[s] | perplexity 93.77
# | epoch 4 |  iter 901 / 1327 | time 1569[s] | perplexity 117.26
# | epoch 4 |  iter 921 / 1327 | time 1576[s] | perplexity 104.68
# | epoch 4 |  iter 941 / 1327 | time 1582[s] | perplexity 111.92
# | epoch 4 |  iter 961 / 1327 | time 1588[s] | perplexity 113.34
# | epoch 4 |  iter 981 / 1327 | time 1595[s] | perplexity 107.92
# | epoch 4 |  iter 1001 / 1327 | time 1601[s] | perplexity 99.02
# | epoch 4 |  iter 1021 / 1327 | time 1608[s] | perplexity 113.27
# | epoch 4 |  iter 1041 / 1327 | time 1616[s] | perplexity 105.15
# | epoch 4 |  iter 1061 / 1327 | time 1623[s] | perplexity 89.28
# | epoch 4 |  iter 1081 / 1327 | time 1631[s] | perplexity 79.15
# | epoch 4 |  iter 1101 / 1327 | time 1639[s] | perplexity 80.23
# | epoch 4 |  iter 1121 / 1327 | time 1645[s] | perplexity 103.65
# | epoch 4 |  iter 1141 / 1327 | time 1652[s] | perplexity 101.28
# | epoch 4 |  iter 1161 / 1327 | time 1658[s] | perplexity 92.79
# | epoch 4 |  iter 1181 / 1327 | time 1664[s] | perplexity 97.79
# | epoch 4 |  iter 1201 / 1327 | time 1671[s] | perplexity 85.99
# | epoch 4 |  iter 1221 / 1327 | time 1678[s] | perplexity 76.70
# | epoch 4 |  iter 1241 / 1327 | time 1684[s] | perplexity 92.19
# | epoch 4 |  iter 1261 / 1327 | time 1690[s] | perplexity 94.91
# | epoch 4 |  iter 1281 / 1327 | time 1697[s] | perplexity 89.27
# | epoch 4 |  iter 1301 / 1327 | time 1703[s] | perplexity 112.02
# | epoch 4 |  iter 1321 / 1327 | time 1709[s] | perplexity 111.18
# evaluating perplexity ...
# 234 / 235
# test perplexity: 134.9986617088592

# %%
import base_model

# %%
class BetterRnnlm(base_model.BaseModel):
    def __init__(self, vocab_size=10000, wordvec_size=650, hidden_size=650, dropout_ratio=650):
        V, D, H = vocab_size , wordvec_size, hidden_size
        rn = np.random.randn

        # 重みの初期化
        embed_W = (rn(V, D) / 100).astype('f')
        lstm_Wx1 = (rn(D, 4 * H) / np.sqrt(D)).astype('f')
        lstm_Wh1 = (rn(H, 4 * H) / np.sqrt(H)).astype('f')
        lstm_b1 = np.zeros(4 * H).astype('f')
        lstm_Wx2 = (rn(H, 4 * H) / np.sqrt(H)).astype('f')
        lstm_Wh2 = (rn(H, 4 * H) / np.sqrt(H)).astype('f')
        lstm_b2 = np.zeros(4 * H).astype('f')
        affine_b = np.zeros(V).astype('f')

        # レイヤの生成
        self.layers = [
            time_layers.TimeEmbedding(embed_W),
            time_layers.TimeDropout(dropout_ratio),
            time_layers.TimeLSTM(lstm_Wx1, lstm_Wh1, lstm_b1, stateful=True),
            time_layers.TimeDropout(dropout_ratio),
            time_layers.TimeLSTM(lstm_Wx2, lstm_Wh2, lstm_b2, stateful=True),
            time_layers.TimeDropout(dropout_ratio),
            time_layers.TimeAffine(embed_W.T, affine_b)
        ]
        self.loss_layer = time_layers.TimeSoftmaxWithLoss()
        self.lstm_layer = [self.layers[2], self.layers[4]]
        self.drop_layer = [self.layers[1], self.layers[3], self.layers[5]]

        # 全ての重みと勾配をリストにまとめる
        self.params, self.grads = [], []
        for layer in self.layers:
            self.params += layer.params
            self.grads += layer.grads
    
    def predict(self, xs, train_flg=True):
        for layer in self.drop_layers:
            layer.train_flg = train_flg
        for layer in self.layers:
            xs = layer.forward(xs)
        return xs
    
    def forward(self, xs, ts, Train_flg=True):
        score = self.predict(xs, Train_flg)
        loss = self.loss_layer.forward(score, ts)
        return loss
    
    def backward(self, dout=1):
        dout = self.loss_layer.backward(dout)
        for layer in reversed(self.layers):
            dout = layer.backward(dout)
        return dout
    
    def reset_state(self):
        for layer in self.lstm_layers:
            layer.reset_state()

# %%
import config

# ハイパーパラメータの設定
batch_size = 20
wordvec_size = 650
hidden_size = 650
time_size = 35
lr = 20.0
max_epoch = 40
max_grad = 0.25
dropout = 0.5

# 学習データの読み込み
corpus, word_to_id, id_to_word = ptb.load_data('train')
corpus_val, _, _ = ptb.load_data('val')
corpus_test, _, _ = ptb.load_data('test')

if config.GPU:
    corpus = util.to_gpu(corpus)
    corpus_val = util.to_gpu(corpus_val)
    corpus_test = util.to_gpu(corpus_test)

vocab_size = len(word_to_id)
xs = corpus[:-1]
ts = corpus[1:]

model = BetterRnnlm(vocab_size, wordvec_size, hidden_size, dropout)
optimizer = optimizer.SGD(lr)
trainer = trainer.RnnlmTrainer(model, optimizer)

best_ppl = float('inf')
for epoch in range(max_epoch):
    trainer.fit(xs, ts, max_epoch=1, batch_size=batch_size,
                time_size=time_size, max_grad=max_grad)

    model.reset_state()
    ppl = util.eval_perplexity(model, corpus_val)
    print('valid perplexity: ', ppl)

    if best_ppl > ppl:
        best_ppl = ppl
        model.save_params()
    else:
        lr /= 4.0
        optimizer.lr = lr

    model.reset_state()
    print('-' * 50)


# テストデータでの評価
model.reset_state()
ppl_test = util.eval_perplexity(model, corpus_test)
print('test perplexity: ', ppl_test)
